# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('happiness_score.csv',
                sep='\t',
                
               header=0,
                names=['Country','Region','Happiness Rank','Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']) 
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df1.count()
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         158
# Freedom                          158
# Trust (Government Corruption)    158
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df1.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.boxplot(df1['Happiness Score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18b5408e250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18b5408e910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18b54081eb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18b5408efd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18b54098370>],
#  'means': []}

# %%
plt.boxplot(df1['Standard Error'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18b540e7220>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18b540e78e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18b540d9e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x18b540e7fa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18b540f2340>],
#  'means': []}

# %%
plt.boxplot(df1['Trust (Government Corruption)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18b5413ad30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18b54148430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18b5413a9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18b54148af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18b54148e50>],
#  'means': []}

# %%
plt.boxplot(df1['Generosity'][:157])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18b541a2610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18b541a2cd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18b541a22b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18b541ac460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18b541ac7c0>],
#  'means': []}

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import zscore
import numpy as np

# %%
df=df1.iloc[:,3:-1]
df
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
plt.boxplot(df['Standard Error'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18b53b47070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18b53b8aca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18b53b381c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18b53b91970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18b53b91cd0>],
#  'means': []}

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.93736005, 0.80592569, 1.36962124, ..., 1.57743784, 2.30965159,
#         0.47103971],
#        [1.91458063, 0.05588945, 1.13522625, ..., 1.33245589, 0.01647953,
#         1.57585637],
#        [1.88479215, 0.8544869 , 1.19286069, ..., 1.4696591 , 2.8427738 ,
#         0.8242928 ],
#        ...,
#        [2.0761992 , 0.13253425, 0.45524543, ..., 1.80923785, 0.38141902,
#         1.85689094],
#        [2.1646885 , 2.26396166, 2.06756644, ..., 2.06447176, 0.35771452,
#         0.31694987],
#        [2.22251319, 1.13418227, 1.58633379, ..., 0.42662099, 0.30180313,
#         0.5581534 ]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 3], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
y=df_new.iloc[:,:1]
y
# Out:
#      Happiness Score
# 0              7.587
# 1              7.561
# 2              7.527
# 3              7.522
# 4              7.427
# ..               ...
# 151            3.587
# 152            3.575
# 154            3.340
# 155            3.006
# 156            2.905
#
# [150 rows x 1 columns]

# %%
x=df_new.iloc[:,1:]
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 151         0.04324                   0.25812  0.85188
# 152         0.03084                   0.31982  0.30285
# 154         0.03656                   0.28665  0.35386
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
df_cor=df_new.corr()
df_cor
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.230613
# Standard Error                       -0.230613        1.000000
# Economy (GDP per Capita)              0.768229       -0.252418
# Family                                0.729256       -0.139711
# Health (Life Expectancy)              0.712668       -0.355582
# Freedom                               0.595397       -0.187750
# Trust (Government Corruption)         0.463775       -0.139232
# Generosity                            0.215231       -0.126499
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.768229  0.729256
# Standard Error                                -0.252418 -0.139711
# Economy (GDP per Capita)                       1.000000  0.625960
# Family                                         0.625960  1.000000
# ...

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df_cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
x1=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x1
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.196283                  0.892961  0.952046
# 1          0.381263                  0.832733  1.000000
# 2          0.185860                  0.847542  0.962115
# 3          0.255180                  0.932918  0.935163
# 4          0.214115                  0.848060  0.927577
# ..              ...                       ...       ...
# 145        0.310938                  0.165048  0.499400
# 146        0.155218                  0.204500  0.000000
# 147        0.227050                  0.183291  0.046399
# 148        0.397714                  0.424065  0.156488
# 149        0.855205                  0.009783  0.102803
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    0.918244  0.993789                       0.853038
# 1                    0.924496  0.938841                       0.287442
# 2                    0.853099  0.969615                       0.982666
# ...

# %%
x1.isnull().sum()
# Out:
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
best_score=0.0

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.6,random_state=i)
    model=LinearRegression()
    model.fit(x_train,y_train)
    s= (model.score(x_test,y_test))
    if(s>best_score):
        best_score=s
        best_state=i
        
print("model score: ",best_score," at random_state: ",best_state)
# Out:
# model score:  0.8298098211304309  at random_state:  44

# %%
best_size=0.0
best_score2=0.0
for i in range(1,10):
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=(i/10),random_state=44)
    model=LinearRegression()
    model.fit(x_train,y_train)
    p=model.score(x_test,y_test)
    if(p>best_score2):
        best_size=i
        best_score2=p
        
print("best train_size is: ",best_size," best score: ",best_score2)
# Out:
# best train_size is:  8  best score:  0.8740235663189455

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=44)
model=LinearRegression()
model.fit(x_train,y_train)
print("the model r2 score is: ",model.score(x_test,y_test))
# Out:
# the model r2 score is:  0.8740235663189455

# %%
pred=model.predict(x_test)

# %%
plt.scatter(y_test,pred)

# %%
sns.distplot((y_test,pred),bins=10)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,pred))
# Out:
# 0.14785344740416137

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,pred))
# Out:
# 0.3038084951140263

# %%
import pickle
happiness_predictor=pickle.dumps(model)

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 0.8740235663189455
